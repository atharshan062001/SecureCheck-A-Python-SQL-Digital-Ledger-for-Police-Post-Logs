# %%
import pandas as pd
sheet_id = "16qEUKckLFy7j1qoSd1bSQURn9QXDb6ffSBAWzRkPsSg";
sheet_name = "sheet1";
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
traffic_df = pd.read_csv(url);
# traffic_df.head()
traffic_df
# Out:
# C:\Users\athar\AppData\Local\Temp\ipykernel_23176\1422845025.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   traffic_df = pd.read_csv(url);
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# ...

# %%
traffic_df.isna().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name              0
# driver_gender             0
# driver_age_raw            0
# driver_age                0
# driver_race               0
# violation_raw             0
# violation                 0
# search_conducted          0
# search_type           21720
# stop_outcome              0
# is_arrested               0
# stop_duration             0
# drugs_related_stop        0
# vehicle_number            0
# dtype: int64

# %%
print(traffic_df['search_type'].describe())
# Out:
# count     43818
# unique        2
# top       Frisk
# freq      21971
# Name: search_type, dtype: object

# %%
traffic_df["violation_raw"].unique()
# Out:
# array(['Drunk Driving', 'Other', 'Signal Violation', 'Speeding',
#        'Seatbelt'], dtype=object)

# %%
traffic_df["violation"].unique()
# Out:
# array(['Speeding', 'Other', 'DUI', 'Seatbelt', 'Signal'], dtype=object)

# %%
traffic_df.drop('violation_raw', axis=1, inplace=True)
traffic_df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race violation  search_conducted     search_type  \
# ...

# %%
print(traffic_df[['driver_age_raw', 'driver_age']].describe())
# Out:
#        driver_age_raw   driver_age
# count    65538.000000  65538.00000
# mean        49.055998     49.11221
# std         18.174699     18.15012
# min         18.000000     18.00000
# 25%         33.000000     34.00000
# 50%         49.000000     49.00000
# 75%         65.000000     65.00000
# max         80.000000     80.00000

# %%
traffic_df.drop('driver_age_raw', axis=1, inplace=True)
traffic_df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age  \
# 0      2020-01-01   0:00:00       Canada             M          19
# 1      2020-01-01   0:01:00        India             M          58
# 2      2020-01-01   0:02:00          USA             M          76
# 3      2020-01-01   0:03:00       Canada             M          76
# 4      2020-01-01   0:04:00       Canada             M          75
# ...           ...       ...          ...           ...         ...
# 65533  2020-02-15  12:13:00        India             F          48
# 65534  2020-02-15  12:14:00       Canada             F          35
# 65535  2020-02-15  12:15:00          USA             M          41
# 65536  2020-02-15  12:16:00       Canada             F          63
# 65537  2020-02-15  12:17:00          USA             F          32
#
#       driver_race violation  search_conducted     search_type stop_outcome  \
# 0           Asian  Speeding              True  Vehicle Search       Ticket
# ...

# %%
traffic_df['driver_gender'] = traffic_df['driver_gender'].replace({'M': 'male', 'F': 'female'})
traffic_df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age  \
# 0      2020-01-01   0:00:00       Canada          male          19
# 1      2020-01-01   0:01:00        India          male          58
# 2      2020-01-01   0:02:00          USA          male          76
# 3      2020-01-01   0:03:00       Canada          male          76
# 4      2020-01-01   0:04:00       Canada          male          75
# ...           ...       ...          ...           ...         ...
# 65533  2020-02-15  12:13:00        India        female          48
# 65534  2020-02-15  12:14:00       Canada        female          35
# 65535  2020-02-15  12:15:00          USA          male          41
# 65536  2020-02-15  12:16:00       Canada        female          63
# 65537  2020-02-15  12:17:00          USA        female          32
#
#       driver_race violation  search_conducted     search_type stop_outcome  \
# 0           Asian  Speeding              True  Vehicle Search       Ticket
# ...

# %%
traffic_df.dtypes
# Out:
# stop_date             object
# stop_time             object
# country_name          object
# driver_gender         object
# driver_age             int64
# driver_race           object
# violation             object
# search_conducted        bool
# search_type           object
# stop_outcome          object
# is_arrested             bool
# stop_duration         object
# drugs_related_stop      bool
# vehicle_number        object
# dtype: object

# %%
traffic_df['stop_date'] = pd.to_datetime(traffic_df['stop_date']).dt.date
traffic_df['stop_date']
# Out:
# 0        2020-01-01
# 1        2020-01-01
# 2        2020-01-01
# 3        2020-01-01
# 4        2020-01-01
#             ...
# 65533    2020-02-15
# 65534    2020-02-15
# 65535    2020-02-15
# 65536    2020-02-15
# 65537    2020-02-15
# Name: stop_date, Length: 65538, dtype: object

# %%
traffic_df['stop_time'] = pd.to_datetime(traffic_df['stop_time'], format='%H:%M:%S').dt.time

# %%
traffic_df.dtypes
# Out:
# stop_date             object
# stop_time             object
# country_name          object
# driver_gender         object
# driver_age             int64
# driver_race           object
# violation             object
# search_conducted        bool
# search_type           object
# stop_outcome          object
# is_arrested             bool
# stop_duration         object
# drugs_related_stop      bool
# vehicle_number        object
# dtype: object

# %%
from sqlalchemy import create_engine

db_user = 'postgres'
db_password = '06062001'
db_host = 'localhost' 
db_port = '5432'      
db_name = 'traffic_stops_data'

# Create connection string
engine = create_engine(f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')

# %%
traffic_df.to_sql('traffic_data', engine, if_exists='replace', index=False)
# Out:
# 538

# %%
result_df = pd.read_sql("SELECT * FROM traffic_data", engine)
print(result_df)
# Out:
#         stop_date stop_time country_name driver_gender  driver_age  \
# 0      2020-01-01  00:00:00       Canada          male          19
# 1      2020-01-01  00:01:00        India          male          58
# 2      2020-01-01  00:02:00          USA          male          76
# 3      2020-01-01  00:03:00       Canada          male          76
# 4      2020-01-01  00:04:00       Canada          male          75
# ...           ...       ...          ...           ...         ...
# 65533  2020-02-15  12:13:00        India        female          48
# 65534  2020-02-15  12:14:00       Canada        female          35
# 65535  2020-02-15  12:15:00          USA          male          41
# 65536  2020-02-15  12:16:00       Canada        female          63
# 65537  2020-02-15  12:17:00          USA        female          32
#
#       driver_race violation  search_conducted     search_type stop_outcome  \
# 0           Asian  Speeding              True  Vehicle Search       Ticket
# ...
